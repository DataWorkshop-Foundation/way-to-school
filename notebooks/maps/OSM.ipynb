# %% [markdown]
# https://deepnote.com/@siew-sook-yan/Python-Retrieving-OpenStreetMap-data-with-OSMNX-NIFhR_zARQm2jYqcctP5hg

# %%
import osmnx as ox
import matplotlib.pyplot as plt
# %matplotlib inline

# Specify the name that is used to seach for the data
place_name = "Bandar Sunway, Petaling Jaya, Selangor" #Malaysia

# Fetch OSM street network from the location
graph = ox.graph_from_place(place_name)
# Out:
# 2022-04-03 12:40:26 Retrieved response from cache file "cache/d80c504605f00efe81bd558f65782189f2394327.json"
# 2022-04-03 12:40:26 Created GeoDataFrame with 1 rows from 1 queries
# 2022-04-03 12:40:26 Constructed place geometry polygon(s) to query API
# 2022-04-03 12:40:26 Projected GeoDataFrame to +proj=utm +zone=47 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-04-03 12:40:27 Projected GeoDataFrame to epsg:4326
# 2022-04-03 12:40:27 Projected GeoDataFrame to +proj=utm +zone=47 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-04-03 12:40:27 Projected GeoDataFrame to epsg:4326
# 2022-04-03 12:40:27 Requesting data within polygon from API in 1 request(s)
# 2022-04-03 12:40:27 Retrieved response from cache file "cache/3ac8854334a50e53c9837c84a6de9eff1e56d5e7.json"
# 2022-04-03 12:40:27 Got all network data within polygon from API in 1 request(s)
# 2022-04-03 12:40:27 Creating graph from downloaded OSM data...
# ...

# %%
type(graph)
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %%
fig, ax = ox.plot_graph(graph)
# Out:
# 2022-04-03 12:40:44 Begin plotting the graph...
# 2022-04-03 12:40:47 Created edges GeoDataFrame from graph
# 2022-04-03 12:40:48 Created nodes GeoDataFrame from graph
# 2022-04-03 12:40:50 Finished plotting the graph

# %%
place_name = "Olsztyn,Warmińsko-Mazurskie, Poland"

# Fetch OSM street network from the location
graph = ox.graph_from_place(place_name)
# Out:
# 2022-04-03 12:40:53 Retrieved response from cache file "cache/bcd71c7f5b3f2adf7fc9af6a7b9bf83ae21ccfcd.json"
# 2022-04-03 12:40:53 Created GeoDataFrame with 1 rows from 1 queries
# 2022-04-03 12:40:53 Constructed place geometry polygon(s) to query API
# 2022-04-03 12:40:53 Projected GeoDataFrame to +proj=utm +zone=34 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-04-03 12:40:53 Projected GeoDataFrame to epsg:4326
# 2022-04-03 12:40:53 Projected GeoDataFrame to +proj=utm +zone=34 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-04-03 12:40:53 Projected GeoDataFrame to epsg:4326
# 2022-04-03 12:40:53 Requesting data within polygon from API in 1 request(s)
# 2022-04-03 12:40:53 Retrieved response from cache file "cache/49debe2fdc311d4682eb249c4804c6d5b800d2ea.json"
# 2022-04-03 12:40:53 Got all network data within polygon from API in 1 request(s)
# 2022-04-03 12:40:53 Creating graph from downloaded OSM data...
# ...

# %%
fig, ax = ox.plot_graph(graph)
# Out:
# 2022-04-03 12:41:44 Begin plotting the graph...
# 2022-04-03 12:41:53 Created edges GeoDataFrame from graph
# 2022-04-03 12:42:04 Created nodes GeoDataFrame from graph
# 2022-04-03 12:42:12 Finished plotting the graph

# %%
area = ox.geocode_to_gdf(place_name)
# Out:
# 2022-04-03 12:45:15 Retrieved response from cache file "cache/bcd71c7f5b3f2adf7fc9af6a7b9bf83ae21ccfcd.json"
# 2022-04-03 12:45:15 Created GeoDataFrame with 1 rows from 1 queries

# %%
type(area)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
area
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  POLYGON ((20.36649 53.78097, 20.36732 53.77957...   53.829016   53.724205
#
#    bbox_east  bbox_west   place_id  osm_type   osm_id        lat        lon  \
# 0  20.566646   20.36649  285325585  relation  2720006  53.776724  20.477781
#
#                                     display_name     class            type  \
# 0  Olsztyn, Warmian-Masurian Voivodeship, Poland  boundary  administrative
#
#    importance
# 0    0.807502

# %%
area.plot()
# Out:
# <AxesSubplot:>

# %%
buildings = ox.geometries_from_place(place_name, tags={'building':True})
# Out:
# 2022-04-03 12:46:11 Retrieved response from cache file "cache/bcd71c7f5b3f2adf7fc9af6a7b9bf83ae21ccfcd.json"
# 2022-04-03 12:46:11 Created GeoDataFrame with 1 rows from 1 queries
# 2022-04-03 12:46:11 Constructed place geometry polygon(s) to query API
# 2022-04-03 12:46:11 Projected GeoDataFrame to +proj=utm +zone=34 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-04-03 12:46:11 Projected GeoDataFrame to epsg:4326
# 2022-04-03 12:46:11 Requesting data within polygon from API in 1 request(s)
# 2022-04-03 12:46:12 Retrieved response from cache file "cache/266a1c14acd2e10c63879c945029cc0c0226a7f0.json"
# 2022-04-03 12:46:12 Got all geometries data within polygon from API in 1 request(s)
# 2022-04-03 12:46:12 Converting 100543 elements in JSON responses to geometries
# 2022-04-03 12:46:13 14741 geometries created in the dict
# 2022-04-03 12:46:13 53 untagged geometries removed
# 2022-04-03 12:46:18 Created r-tree spatial index for 14688 geometries
# ...

# %%
len(buildings)
# Out:
# 14518

# %%
buildings.head(5)
# Out:
#                         addr:city addr:housenumber          addr:street  \
# element_type osmid
# node         1604918101       NaN              NaN                  NaN
#              2498333332   Olsztyn                2       Armii Krajowej
#              2857860898   Olsztyn               13  Aleksandra Puszkina
# way          42977200     Olsztyn                1   plac Jana Pawła II
#              42977201     Olsztyn                1         Staromiejska
#
#                           amenity                   name  \
# element_type osmid
# node         1604918101       NaN            MPK Olsztyn
#              2498333332      fuel                   Moya
#              2857860898   doctors              NZOZ VITA
# way          42977200    townhall  Urząd Miasta Olsztyna
#              42977201         NaN           Wysoka Brama
#
#                                                                   operator  \
# element_type osmid
# ...

# %%
buildings.amenity.unique()
# Out:
# array([nan, 'fuel', 'doctors', 'townhall', 'clinic', 'public_building',
#        'parking', 'place_of_worship', 'post_office', 'restaurant',
#        'school', 'childcare', 'ice_cream', 'pharmacy', 'university',
#        'car_wash', 'fire_station', 'library', 'fast_food', 'courthouse',
#        'theatre', 'dentist', 'social_facility', 'kindergarten', 'bank',
#        'pub', 'studio', 'police', 'waste_disposal', 'shelter', 'toilets',
#        'veterinary'], dtype=object)

# %%
school = ox.geometries_from_place(place_name, 
                                  tags={"amenity": "school"}
                                 )
# Out:
# 2022-04-03 12:47:41 Retrieved response from cache file "cache/bcd71c7f5b3f2adf7fc9af6a7b9bf83ae21ccfcd.json"
# 2022-04-03 12:47:41 Created GeoDataFrame with 1 rows from 1 queries
# 2022-04-03 12:47:41 Constructed place geometry polygon(s) to query API
# 2022-04-03 12:47:41 Projected GeoDataFrame to +proj=utm +zone=34 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-04-03 12:47:41 Projected GeoDataFrame to epsg:4326
# 2022-04-03 12:47:41 Requesting data within polygon from API in 1 request(s)
# 2022-04-03 12:47:41 Retrieved response from cache file "cache/30d90be2f37e509e69e40707c71b9c543951f753.json"
# 2022-04-03 12:47:41 Got all geometries data within polygon from API in 1 request(s)
# 2022-04-03 12:47:41 Converting 660 elements in JSON responses to geometries
# 2022-04-03 12:47:41 72 geometries created in the dict
# 2022-04-03 12:47:42 2 untagged geometries removed
# 2022-04-03 12:47:42 Created r-tree spatial index for 70 geometries
# ...

# %%
kindergarten = ox.geometries_from_place(place_name, 
                                  tags={"amenity": "kindergarten"}
                                 )
# Out:
# 2022-04-03 12:42:45 Retrieved response from cache file "cache/bcd71c7f5b3f2adf7fc9af6a7b9bf83ae21ccfcd.json"
# 2022-04-03 12:42:45 Created GeoDataFrame with 1 rows from 1 queries
# 2022-04-03 12:42:45 Constructed place geometry polygon(s) to query API
# 2022-04-03 12:42:45 Projected GeoDataFrame to +proj=utm +zone=34 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-04-03 12:42:45 Projected GeoDataFrame to epsg:4326
# 2022-04-03 12:42:45 Requesting data within polygon from API in 1 request(s)
# 2022-04-03 12:42:45 Resolved overpass-api.de to 178.63.48.217
# 2022-04-03 12:42:45 Pausing 0 seconds before making HTTP POST request
# ...

# %%
len(school)
# Out:
# 63

# %%
school.head()
# Out:
#                        amenity                        email  \
# element_type osmid
# node         461803332  school  sekretariat@sp12.olsztyn.eu
#              461804137  school                          NaN
#              520131716  school                          NaN
#              520131720  school                          NaN
#              521837970  school       sp311@cyfroweszkoly.pl
#
#                                                                      name  \
# element_type osmid
# node         461803332                            Szkoła podstawowa nr 12
#              461804137  Zespół Szkół Ogólnokształcących nr 3, Szkoła P...
#              520131716              Liceum Ogólnokształcące dla Dorosłych
#              520131720  II Liceum Ogólnokształcące im. K. I. Gałczyńsk...
#              521837970  Szkoła podstawowa nr 311 z oddziałami dwujęzyc...
#
#                                    phone ref:rspo  \
# element_type osmid
# ...

# %%
cols = ['name', 'street']

# %%
nodes, edges = ox.graph_to_gdfs(graph)
# Out:
# 2022-04-03 12:46:39 Created nodes GeoDataFrame from graph
# 2022-04-03 12:46:49 Created edges GeoDataFrame from graph

# %%
nodes.head()
# Out:
#                   y          x  street_count highway  \
# osmid
# 52860101  53.745101  20.458539             3     NaN
# 52860106  53.746664  20.459519             4     NaN
# 52860114  53.746515  20.460190             3     NaN
# 52860172  53.746702  20.459348             3     NaN
# 52860184  53.742747  20.456898             3     NaN
#
#                            geometry
# osmid
# 52860101  POINT (20.45854 53.74510)
# 52860106  POINT (20.45952 53.74666)
# 52860114  POINT (20.46019 53.74652)
# 52860172  POINT (20.45935 53.74670)
# 52860184  POINT (20.45690 53.74275)

# %%
edges.head()
# Out:
#                              osmid  oneway lanes  ref  \
# u        v          key
# 52860101 52860106   0    383178234    True     2  527
#          132059879  0    391919601   False   NaN  NaN
# 52860106 3581139215 0     13872176   False   NaN  NaN
#          52860172   0     13872176   False   NaN  NaN
#          3581139210 0    180826546    True     2  527
#
#                                                        name      highway  \
# u        v          key
# 52860101 52860106   0                      Aleja Warszawska    secondary
#          132059879  0                             Słoneczna  residential
# 52860106 3581139215 0    Profesora Kazimierza Kalinowskiego  residential
#          52860172   0    Profesora Kazimierza Kalinowskiego  residential
#          3581139210 0                      Aleja Warszawska    secondary
#
#                         maxspeed   length  \
# u        v          key
# 52860101 52860106   0         50  185.324
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))

# %%
fig, ax = plt.subplots(figsize=(12,8))

# Plot the footprint
area.plot(ax=ax, facecolor='black')
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(15,8))

# Plot the footprint
area.plot(ax=ax, facecolor='black')

# Plot street edges
edges.plot(ax=ax, linewidth=1, edgecolor='#BC8F8F')
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(20,8))

# Plot the footprint
area.plot(ax=ax, facecolor='black')

# Plot street edges
edges.plot(ax=ax, linewidth=1, edgecolor='#BC8F8F')

# Plot schools
school.plot(ax=ax, color='blue', alpha=0.8, markersize=20)
plt.tight_layout()

# Plot kindergarden
kindergarten.plot(ax=ax, color='red', alpha=0.8, markersize=20)
plt.tight_layout()

# %% [markdown]
# Re-project layers to EPSG:3067

# %%
from pyproj import CRS

# %%
projection = CRS.from_epsg(3067)

# Re-project layers
area = area.to_crs(projection)
edges = edges.to_crs(projection)
buildings = buildings.to_crs(projection)
school = school.to_crs(projection)

# %%
fig, ax = plt.subplots(figsize=(12,8))

# Plot the footprint
area.plot(ax=ax, facecolor='black')

# Plot street edges
edges.plot(ax=ax, linewidth=1, edgecolor='dimgray')

# Plot buildings
buildings.plot(ax=ax, facecolor='silver', alpha=0.7)

# Plot school
school.plot(ax=ax, color='yellow', alpha=0.7, markersize=10)

# Plot kindergarten
kindergarten.plot(ax=ax, color='red', alpha=0.7, markersize=10)
plt.tight_layout()

# %%
import osmnx as ox
import networkx as nx

# %%
ox.config(log_console=True, use_cache=True)
# Out:
# 2022-04-03 12:56:03 Configured OSMnx 1.1.2
# 2022-04-03 12:56:03 HTTP response caching is on

# %%
# define the start and end locations in latlng
start_latlng = (53.76327, 20.49001)
end_latlng = (53.76631, 20.49146)

# %%
# location where you want to find your route
place = 'Olsztyn, Warmińsko-Mazurskie, Poland'

# %%
# find shortest route based on the mode of travel
mode = 'walk'        # 'drive', 'bike', 'walk'

# %%
# find shortest path based on distance or time
optimizer = 'time'        # 'length','time'

# %%
# create graph from OSM within the boundaries of some 
# geocodable place(s)
graph = ox.graph_from_place(place, network_type = mode)
# Out:
# 2022-04-03 13:05:21 Pausing 1 seconds before making HTTP GET request
# 2022-04-03 13:05:22 Get https://nominatim.openstreetmap.org/search?format=json&polygon_geojson=1&dedupe=0&limit=50&q=Olsztyn%2C+Warmi%C5%84sko-Mazurskie%2C+Poland with timeout=180
# 2022-04-03 13:05:22 Resolved nominatim.openstreetmap.org to 184.104.226.109
# 2022-04-03 13:05:22 Downloaded 61.9kB from nominatim.openstreetmap.org
# 2022-04-03 13:05:23 Saved response to cache file "cache/ac0ae2f3bec69578cd4a2b64bfdee5826d2f526a.json"
# 2022-04-03 13:05:23 Created GeoDataFrame with 1 rows from 1 queries
# 2022-04-03 13:05:23 Constructed place geometry polygon(s) to query API
# 2022-04-03 13:05:23 Projected GeoDataFrame to +proj=utm +zone=34 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-04-03 13:05:23 Projected GeoDataFrame to epsg:4326
# 2022-04-03 13:05:23 Projected GeoDataFrame to +proj=utm +zone=34 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# ...

# %%
# find the nearest node to the start location
orig_node = ox.get_nearest_node(graph, start_latlng)
# Out:
# 2022-04-03 13:06:53 Created nodes GeoDataFrame from graph
# /home/magdalena/Dokumenty/way-to-school/venv/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)

# %%
# find the nearest node to the end location
dest_node = ox.get_nearest_node(graph, end_latlng)
# Out:
# 2022-04-03 13:06:54 Created nodes GeoDataFrame from graph
# /home/magdalena/Dokumenty/way-to-school/venv/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)

# %%
#  find the shortest path
shortest_route = nx.shortest_path(graph,
                                  orig_node,
                                  dest_node,
                                  weight=optimizer)

# %%
shortest_route_map = ox.plot_route_folium(graph, shortest_route)
shortest_route_map
# Out:
# 2022-04-03 13:06:56 Created edges GeoDataFrame from graph
# ...

# %%
shortest_route_map = ox.plot_route_folium(graph, shortest_route, 
                                          tiles='openstreetmap')
shortest_route_map
# Out:
# 2022-04-03 13:08:56 Created edges GeoDataFrame from graph
# ...

# %%
import folium
folium.TileLayer('openstreetmap').add_to(shortest_route_map)
folium.TileLayer('Stamen Terrain').add_to(shortest_route_map)
folium.TileLayer('Stamen Toner').add_to(shortest_route_map)
folium.TileLayer('Stamen Water Color').add_to(shortest_route_map)
folium.TileLayer('cartodbpositron').add_to(shortest_route_map)
folium.TileLayer('cartodbdark_matter').add_to(shortest_route_map)
folium.LayerControl().add_to(shortest_route_map)
shortest_route_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
location.point
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/magdalena/Dokumenty/way-to-school/notebooks/OSM.ipynb Cell 44' in <module>
# ----> <a href='vscode-notebook-cell:/home/magdalena/Dokumenty/way-to-school/notebooks/OSM.ipynb#ch0000048?line=0'>1</a> location.point
#
# NameError: name 'location' is not defined
